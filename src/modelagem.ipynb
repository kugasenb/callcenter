# %%
# %pip install -r /Workspace/Users/lucasenb1@gmail.com/callcenter/requirements.txt

# %%
import pandas as pd
import time
from pyspark.sql import functions as f
from pyspark.sql import types as t
